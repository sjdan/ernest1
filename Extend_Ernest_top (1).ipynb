# %%
run expt_design.py --min-parts 4 --max-parts 32 --total-parts 256 --min-mcs 1 --max-mcs 8 --cores-per-mc 4
# Out:
# Machines, Cores, InputFraction, Partitions, Weight
# 3, 12, 0.050164, 13, 1.000010
# 4, 16, 0.061678, 16, 1.000010
# 3, 12, 0.061678, 16, 1.000006
# 3, 12, 0.055921, 15, 1.000005
# 1, 4, 0.015625, 4, 1.000004
# 1, 4, 0.021382, 6, 1.000004
# 8, 32, 0.125000, 32, 1.000002

# %%
run hw_pp.py expt_1op.csv
# Out:
# Cores  12 HW3_pipeline sample:  0.050164  took  2.3692288398742676
# Cores  16 HW3_pipeline sample:  0.061678  took  2.407705783843994
# Cores  12 HW3_pipeline sample:  0.061678  took  2.357356548309326
# Cores  12 HW3_pipeline sample:  0.055921  took  2.3266031742095947
# Cores  4 HW3_pipeline sample:  0.015625  took  1.9851126670837402
# Cores  4 HW3_pipeline sample:  0.021382  took  2.308809995651245
# Cores  32 HW3_pipeline sample:  0.125  took  2.461057424545288

# %%
run predictor.py examples_1op.csv
# Out:
# Fitting a model with  7  points
# 2.313611386077928   12
# 2.3325972438454565   16
# 2.4291335022753686   12
# 2.3713724441766484   12
# 2.0584684185302056   4
# 2.2317515928263667   4
# 2.4789398462680277   32
# Prediction ratios are 97.65%, 96.88%, 103.04%, 101.92%, 103.7%, 96.66%, 100.73%
# Machines, Predicted Time, Actual Time, MSE for data obtained from Optimal Experiment
# 12   2.313611386077928   2.36922884   0.003093361923999994
# 16   2.3325972438454565   2.407705784   0.005641361881000047
# 12   2.4291335022753686   2.357356548   0.005151937728999997
# 12   2.3713724441766484   2.326603174   0.002004263361000005
# 4   2.0584684185302056   1.985112667   0.005380956025000008
# 4   2.2317515928263667   2.308809996   0.005937935363999942
# 32   2.4789398462680277   2.461057425   0.00031980168900001127
# Machines, Predicted Time for 15 different models
# 4 31.687724054761492
# 8 16.77810055671535
# 12 11.843493682457314
# 16 9.393367378981916
# 20 7.933509836814777
# ...

# %%
run optimal.py --min-parts 4 --max-parts 32 --skew 1.42 --total-parts 256 --min-mcs 1 --max-mcs 8 --cores-per-mc 4
# Out:
# Machines, Cores, InputFraction, Partitions, Weight
# 4, 16, 0.061678, 16, 0.999996
# 8, 32, 0.125000, 32, 0.999899
# 3, 12, 0.055921, 15, 0.999803
# 3, 12, 0.050164, 13, 0.999540
# 1, 4, 0.015625, 4, 0.998061
# 1, 4, 0.021382, 6, 0.579595

# %%
run hw_pp.py opt_1op.csv
# Out:
# Cores  16 HW3_pipeline sample:  0.061678  took  2.37357497215271
# Cores  32 HW3_pipeline sample:  0.125  took  2.6304666996002197
# Cores  12 HW3_pipeline sample:  0.055921  took  2.3989107608795166
# Cores  12 HW3_pipeline sample:  0.050164  took  1.9032657146453857
# Cores  4 HW3_pipeline sample:  0.015625  took  2.2423551082611084
# Cores  4 HW3_pipeline sample:  0.021382  took  2.3690378665924072

# %%
run predictor_skew.py examples_1op.csvc
# Out:
# Fitting a model with  6  points
# 2.295537358340173   16
# 2.570735446760521   32
# 2.350410233867954   12
# 2.277882048959962   12
# 2.102730740173707   4
# 2.320315294897684   4
# Prediction ratios are 96.71%, 97.73%, 97.98%, 119.68%, 93.77%, 97.94%
# Machines, Predicted Time, Actual Time, MSE for data obtained from Optimal Experiment
# 16   2.295537358340173   2.373574972   0.0060899294440000425
# 32   2.570735446760521   2.6304667   0.0035679118239999876
# 12   2.350410233867954   2.398910761   0.0023523470009999907
# 12   2.277882048959962   1.903265715   0.14033714745600004
# 4   2.102730740173707   2.242355108   0.01949486137599999
# 4   2.320315294897684   2.369037867   0.0023739307290000285
# Machines, Predicted Time for 15 different models
# 4 39.30696837373543
# 8 20.476435644930763
# 12 14.244163278813668
# 16 11.161456003368466
# 20 9.338574764192018
# 24 8.145606543149949
# 28 7.312588618184668
# 32 6.704539628267378
# 36 6.2464699283820835
# 40 5.893385731519187
# ...
